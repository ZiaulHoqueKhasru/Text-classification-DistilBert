# %%
import sagemaker
print("sagemaker =", sagemaker.__version__)
# !pip install --upgrade --force-reinstall --no-cache-dir "sagemaker==2.245.0"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker = 2.245.0

# %%
# !pip install transformers
# !pip install -U sagemaker
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.12/site-packages (4.57.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/conda/lib/python3.12/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.12/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/conda/lib/python3.12/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (2025.10.5)

# %%
from sagemaker.huggingface import HuggingFaceModel
from sagemaker import get_execution_role

role = get_execution_role()
model_s3_path = 's3://sagemaker-text-classifier-uci-news-aggregation/output/huggingface-pytorch-training-2026-01-13-17-38-35-955/output/model.tar.gz'
#model_s3_path = 's3://hugging-face-multiclass-textclassification-bucket/output/huggingface-pytorch-training-2024-07-08-08-10-28-142/output/model.tar.gz'
huggingface_model = HuggingFaceModel(

    model_data = model_s3_path,
    role = role,
    transformers_version = '4.48.0',#in deployment found this stable after several try
    pytorch_version= '2.3.0',#this is must in deployment end of 2025
    py_version = 'py311',
    entry_point = 'inference.py',
    name = "load-testing-model" #the model will be created by this name in aws models section  
)

# %% [markdown]
# # after finising i must delete the end point
# sagemaker -> Deployment and Inference -> endpoint -> delele

# %%
predictor = huggingface_model.deploy(
    initial_instance_count= 1,
    instance_type= 'ml.m5.xlarge',#ml.t3.xlarge was not supporting
    endpoint_name= 'multiclass-text-classification-endpoint-ziaV1'#after delteing this i need to set another new name when re run it,because it requres unique endpoint name
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/utils.py:623 in _create_or_update_code_dir     │
# │                                                                                                  │
# │    620 │   │   if not os.path.exists(code_dir):                                                  │
# │    621 │   │   │   os.mkdir(code_dir)                                                            │
# │    622 │   │   try:                                                                              │
# │ ❱  623 │   │   │   shutil.copy2(inference_script, code_dir)                                      │
# │    624 │   │   except FileNotFoundError:                                                         │
# │    625 │   │   │   if os.path.exists(os.path.join(code_dir, inference_script)):                  │
# │    626 │   │   │   │   pass                                                                      │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/shutil.py:475 in copy2                                                 │
# │                                                                                                  │
# │    472 │   │   │   else:                                                                         │
# │    473 │   │   │   │   raise                                                                     │
# │    474 │                                                                                         │
# │ ❱  475 │   copyfile(src, dst, follow_symlinks=follow_symlinks)                                   │
# │    476 │   copystat(src, dst, follow_symlinks=follow_symlinks)                                   │
# │    477 │   return dst                                                                            │
# │    478                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/shutil.py:260 in copyfile                                              │
# │                                                                                                  │
# │    257 │   if not follow_symlinks and _islink(src):                                              │
# │    258 │   │   os.symlink(os.readlink(src), dst)                                                 │
# │    259 │   else:                                                                                 │
# │ ❱  260 │   │   with open(src, 'rb') as fsrc:                                                     │
# │    261 │   │   │   try:                                                                          │
# │    262 │   │   │   │   with open(dst, 'wb') as fdst:                                             │
# │    263 │   │   │   │   │   # macOS                                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: [Errno 2] No such file or directory: 'Text-classification-DistilBert/inference.py'
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 predictor = huggingface_model.deploy(                                                        │
# │   2 │   initial_instance_count= 1,                                                               │
# │   3 │   instance_type= 'ml.m5.xlarge',#ml.t3.xlarge was not supporting                           │
# │   4 │   endpoint_name= 'multiclass-text-classification-endpoint-ziaV1'#after delteing this i     │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/huggingface/model.py:326 in deploy             │
# │                                                                                                  │
# │   323 │   │   │   │   inference_tool=inference_tool,                                             │
# │   324 │   │   │   )                                                                              │
# │   325 │   │                                                                                      │
# │ ❱ 326 │   │   return super(HuggingFaceModel, self).deploy(                                       │
# │   327 │   │   │   initial_instance_count,                                                        │
# │   328 │   │   │   instance_type,                                                                 │
# │   329 │   │   │   serializer,                                                                    │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/model.py:1737 in deploy                        │
# │                                                                                                  │
# │   1734 │   │   │   return None                                                                   │
# │   1735 │   │                                                                                     │
# │   1736 │   │   else:  # existing single model endpoint path                                      │
# │ ❱ 1737 │   │   │   self._create_sagemaker_model(                                                 │
# │   1738 │   │   │   │   instance_type=instance_type,                                              │
# │   1739 │   │   │   │   accelerator_type=accelerator_type,                                        │
# │   1740 │   │   │   │   tags=tags,                                                                │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/model.py:936 in _create_sagemaker_model        │
# │                                                                                                  │
# │    933 │   │   │   if self.name is None and model_package.name is not None:                      │
# │    934 │   │   │   │   self.name = model_package.name                                            │
# │    935 │   │   else:                                                                             │
# │ ❱  936 │   │   │   container_def = self.prepare_container_def(                                   │
# │    937 │   │   │   │   instance_type,                                                            │
# │    938 │   │   │   │   accelerator_type=accelerator_type,                                        │
# │    939 │   │   │   │   serverless_inference_config=serverless_inference_config,                  │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/huggingface/model.py:531 in                    │
# │ prepare_container_def                                                                            │
# │                                                                                                  │
# │   528 │   │   │   )                                                                              │
# │   529 │   │                                                                                      │
# │   530 │   │   deploy_key_prefix = model_code_key_prefix(self.key_prefix, self.name, deploy_ima   │
# │ ❱ 531 │   │   self._upload_code(deploy_key_prefix, repack=True)                                  │
# │   532 │   │   deploy_env = dict(self.env)                                                        │
# │   533 │   │   deploy_env.update(self._script_mode_env_vars())                                    │
# │   534                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/model.py:831 in _upload_code                   │
# │                                                                                                  │
# │    828 │   │   │   │   repacked_model_data,                                                      │
# │    829 │   │   │   )                                                                             │
# │    830 │   │   │                                                                                 │
# │ ❱  831 │   │   │   utils.repack_model(                                                           │
# │    832 │   │   │   │   inference_script=self.entry_point,                                        │
# │    833 │   │   │   │   source_directory=self.source_dir,                                         │
# │    834 │   │   │   │   dependencies=self.dependencies,                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/utils.py:562 in repack_model                   │
# │                                                                                                  │
# │    559 │   with _tmpdir(directory=local_download_dir) as tmp:                                    │
# │    560 │   │   model_dir = _extract_model(model_uri, sagemaker_session, tmp)                     │
# │    561 │   │                                                                                     │
# │ ❱  562 │   │   _create_or_update_code_dir(                                                       │
# │    563 │   │   │   model_dir,                                                                    │
# │    564 │   │   │   inference_script,                                                             │
# │    565 │   │   │   source_directory,                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/utils.py:628 in _create_or_update_code_dir     │
# │                                                                                                  │
# │    625 │   │   │   if os.path.exists(os.path.join(code_dir, inference_script)):                  │
# │    626 │   │   │   │   pass                                                                      │
# │    627 │   │   │   else:                                                                         │
# │ ❱  628 │   │   │   │   raise FileNotFoundError(                                                  │
# │    629 │   │   │   │   │   f"Could not find '{inference_script}'. Common solutions:\n"           │
# │    630 │   │   │   │   │   "1. Make sure inference.py exists in the code/ directory\n"           │
# │    631 │   │   │   │   │   "2. Package your model correctly:\n"                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: Could not find 'Text-classification-DistilBert/inference.py'. Common solutions:
# 1. Make sure inference.py exists in the code/ directory
# 2. Package your model correctly:
#    - ✅ DO: Navigate to the directory containing model files and run:
#      cd /path/to/model_files
#      tar czvf ../model.tar.gz *
#    - ❌ DON'T: Create from parent directory:
#      tar czvf model.tar.gz model/
#
# Expected structure in model.tar.gz:
#    ├── model.pth (or your model file)
#    └── code/
#        ├── inference.py
#        └── requirements.txt
#
# For more details, see the documentation:
# https://sagemaker.readthedocs.io/en/stable/frameworks/pytorch/using_pytorch.html#bring-your-own-model

# %%
data = {"inputs": "Covid19 is dengerious"}
prediction = predictor.predict(data)
prediction

# %%
data = {"inputs": "Stock market hit at all time low"}
prediction = predictor.predict(data)
prediction
